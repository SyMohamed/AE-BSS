# %%
import torch
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm 
from sklearn.utils import shuffle
import random
# %matplotlib inline
import torch.nn as nn
from my_utils import np_norm_decoder
import torch.nn.functional as F
import os
# plt.style.use('dark_background')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

seed = 10
def set_seed(seed):
    print("Set Seed to",seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
device
# Out:
# device(type='cuda')

# %%
met_abs = pd.read_csv('/home/sym/ASPACC BSS/data/1311/methane_abs.csv', delimiter=',', header=None, skiprows=2).to_numpy()
eth_abs = pd.read_csv('/home/sym/ASPACC BSS/data/1311/ethane_abs.csv', delimiter=',', header=None, skiprows=2).to_numpy()
ethy_abs = pd.read_csv('/home/sym/ASPACC BSS/data/1311/ethylene_abs.csv', delimiter=',', header=None, skiprows=2).to_numpy()
prop_abs = pd.read_csv('/home/sym/ASPACC BSS/data/1311/propyne_abs.csv', delimiter=',', header=None, skiprows=2).to_numpy()
v=np.linspace(2989.5, 2984.5, len(met_abs))

# %%
import numpy as np


import numpy as np

def augment_signals_nonlinear(dataset,
                              noise_frac=0.0,
                              baseline_frac=0.0,
                              max_shift=0):
    """
    dataset: array (N, L) of clean signals
    returns:
      features: array (N, L+3) where columns are
        [0:L]      = augmented spectrum
        [L]        = shift (int)
        [L+1]      = quadratic coeff a
        [L+2]      = linear coeff  b
    """
    N, L = dataset.shape
    σ = noise_frac    * np.std(dataset, axis=None)
    baseline_max = baseline_frac * np.max(dataset, axis=None)
    t = np.linspace(0, 1, L)

    features = np.zeros((N, L + 3), dtype=dataset.dtype)

    for i in range(N):
        clean = dataset[i].copy()

        # 1) random shift
        shift = np.random.randint(-max_shift, max_shift + 1)
        aug = np.roll(clean, shift)

        # 2) baseline drift (quadratic + linear only)
        a = np.random.uniform(-baseline_max, baseline_max)
        b = np.random.uniform(-baseline_max, baseline_max)
        baseline = a * t**2 + b * t
        aug = aug + baseline

        # 3) additive noise
        noise = np.random.randn(L) * σ
        aug = aug + noise

        # pack
        features[i, :L]   = aug
        features[i,   L]  = shift
        features[i, L+1]  = a
        features[i, L+2]  = b

    return features
# --- Usage example ---
Nobs = 1000
Con = np.zeros([int(Nobs),4])
Con[:,0] = np.random.random([int(Nobs)])
Con[:,1] = np.random.random([int(Nobs)])
Con[:,2] = np.random.random([int(Nobs)])
Con[:,3] = np.random.random([int(Nobs)])

dataset_clean=np.matmul(Con,[met_abs[:,4], eth_abs[:,4],ethy_abs[:,4]/2,prop_abs[:,4]]) #,df1[9] ,df1[10]]

dataset_aug = augment_signals_nonlinear(dataset_clean,
                                        noise_frac=0.0,
                                        baseline_frac=0.2,
                                        max_shift=3)

# Plot an example
plt.figure(figsize=(10,6))
plt.plot(dataset_clean[59], label="clean")
plt.plot(dataset_aug[59,:600],  label="augmented")
plt.xlabel("x")
plt.legend()
plt.show()

# %%
Nobs=10000
Con = np.zeros([int(Nobs),4])
Con[:,0] = np.random.random([int(Nobs)])
Con[:,1] = np.random.random([int(Nobs)])
Con[:,2] = np.random.random([int(Nobs)])
Con[:,3] = np.random.random([int(Nobs)])
plt.style.use('default')
Con[:,3] = np.random.random([int(Nobs)])
dataset_clean=np.matmul(Con,[met_abs[:,4], eth_abs[:,4] ,ethy_abs[:,4]/2, prop_abs[:,4]]) #,df1[9] ,df1[10]]
fig = plt.figure(figsize=(10, 6), dpi=80)
plt.plot(dataset_clean[5,:])
plt.xlabel('x')

Con2=np.copy(Con)

# %%
paired_signals_2=augment_signals_nonlinear(dataset_clean, noise_frac=0.1,
                                        baseline_frac=0.2,
                                        max_shift=5)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example placeholders (replace with real data)
# v = np.linspace(2989.5, 2984.5, 600)
# paired_signals_2 = np.random.randn(200, 600)
# dataset_clean = np.random.randn(200, 600)

plt.figure(figsize=(8, 6))

plt.plot(v, paired_signals_2[100, :600], label='Augmented Spectrum', linewidth=2.5, color='tab:orange')
plt.plot(v, dataset_clean[100], label='Clean Spectrum', linewidth=2.5, color='tab:blue')

plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=18)
plt.ylabel('Absorbance', fontsize=18)
plt.legend(fontsize=14)
plt.grid(True, which='both', alpha=0.3)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
# plt.savefig('/home/sym/ASPACC BSS/plots/noisy_clean.pdf', transparent=True, dpi=300)
# plt.savefig('/home/sym/ASPACC BSS/plots/noisy_clean.png', transparent=True, dpi=150)
plt.show()
plt.show()

# %%
# leanring parameters
epochs =500
batch_size = 128
lr = 0.001

# Reshaping data
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

Spec_T = torch.tensor(dataset_clean)
Con_T = torch.tensor(Con)

train_features = Spec_T[:int(Nobs*1)]      #60% of df
val_features   = Spec_T[int(Nobs*0.9):int(Nobs)]#20% of df
test_features  = Spec_T[int(Nobs*0.9):int(Nobs)]#20% of df

train_targets = Con_T[:int(Nobs*1)]      #60% of df
val_targets   = Con_T[int(Nobs*0.9):int(Nobs)]#20% of df
test_targets  = Con_T[int(Nobs*0.9):int(Nobs)]#20% of df

train = torch.utils.data.TensorDataset(torch.Tensor(np.array(train_features)).to(device), torch.Tensor(np.array(train_targets)).to(device))
train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)

val = torch.utils.data.TensorDataset(torch.Tensor(np.array(val_features)).to(device), torch.Tensor(np.array(val_targets)).to(device))
valid_loader = torch.utils.data.DataLoader(val, batch_size = batch_size)

test = torch.utils.data.TensorDataset(torch.Tensor(np.array(test_features)).to(device), torch.Tensor(np.array(test_targets)).to(device))
test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size)

# %%
import torch
import torch.nn as nn

# Convert the Pandas Series to PyTorch tensors and then squeeze them to get the correct shape
CH4_tensor = torch.tensor(met_abs[:,1]).float().squeeze()
C2H6_tensor = torch.tensor(eth_abs[:,1]).float().squeeze()
C2H4_tensor = torch.tensor(ethy_abs[:,1]/2).float().squeeze()
C3H4_tensor = torch.tensor(prop_abs[:,1]).float().squeeze()

# Stack the tensors along a new dimension to create a tensor of shape [3, 602]
stacked_tensors = torch.stack([CH4_tensor, C2H6_tensor, C2H4_tensor, C3H4_tensor], dim=0)
#, C2H6_tensor, C3H4_tensor],
# Create the parameter
# self.r = nn.Parameter(stacked_tensors, requires_grad=True)

shape1=np.shape(met_abs)
noise=torch.rand((4, shape1[0]))

# %%
class Encoder(nn.Module):
    def __init__(self, latent_dims=4):
        super(Encoder, self).__init__()
        self.conv1 = nn.Conv1d(1, 128, 5, padding=2)
        self.bn1 = nn.BatchNorm1d(128)
        self.conv2 = nn.Conv1d(128, 128, 5, padding=2)
        self.bn2 = nn.BatchNorm1d(128)
        self.conv3 = nn.Conv1d(128, 128, 5, padding=2)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(2, 2)
        self.conv4 = nn.Conv1d(128, 64, 5, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.pool2 = nn.MaxPool1d(2, 2)
        self.conv5 = nn.Conv1d(64, 32, 5, padding=2)
        self.bn5 = nn.BatchNorm1d(32)
        self.pool3 = nn.MaxPool1d(2, 2)
        self.conv6 = nn.Conv1d(32, 16, 5, padding=2)
        self.bn6 = nn.BatchNorm1d(16)
        self.dropout = nn.Dropout(p=0.2)
        self.inter = nn.Linear(12 * 100, 18)  # intermediate fc layer
        self.linear2 = nn.Linear(18, latent_dims)  # intermediate fc layer

    def forward(self, x):
        x = x.unsqueeze(1)
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool1(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.pool2(x)
        x = F.relu(self.bn5(self.conv5(x)))
        x = self.pool3(x)
        x = F.relu(self.bn6(self.conv6(x)))
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.inter(x)
        z = self.linear2(x)
        if (z.max(axis=0).values - z.min(axis=0).values)[0] != 0 and (z.max(axis=0).values - z.min(axis=0).values)[1] != 0:
            z = (z - z.min(axis=0).values) / (z.max(axis=0).values - z.min(axis=0).values)
        return z
shape1=np.shape(met_abs)
latent_dims=4
class Decoder(nn.Module):
    def __init__(self, latent_dims=latent_dims):
        super(Decoder, self).__init__()
        self.r = nn.Parameter(stacked_tensors, requires_grad=True)
        # self.r = nn.Parameter(noise, requires_grad=True)

    def forward(self, z):
        x=torch.matmul(z,self.r)
        return z,x
class Autoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(Autoencoder, self).__init__()
        self.encoder = Encoder(latent_dims)
        self.decoder = Decoder(latent_dims)

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %%
import pandas as pd

def train(autoencoder, train_loader, valid_loader, epochs=500):
    losses = {'train': [], 'validation': []}
    valid_loss_min = np.Inf
    opt = torch.optim.Adam(autoencoder.parameters(), lr=1e-2)

    r_values = []  # List to store self.r values at each epoch
    x_hat_values = []  # List to store x_hat values at each epoch

    for epoch in range(epochs):
        train_loss = 0.0
        valid_loss = 0.0
        autoencoder.train()

        for x, y in train_loader:
            x = x.to(device)
            opt.zero_grad()

            # Real data reconstruction
            z, x_hat = autoencoder(x)
            reconstruction_loss = ((x - x_hat)**2).sum()

            # Synthetic loss
            z_synth, x_hat_synth = autoencoder(x_hat)
            synthetic_loss = ((z_synth - z)**2).sum()
            
            # Total loss: combine real and synthetic losses
            loss = reconstruction_loss + 1 * synthetic_loss
            loss.backward()
            opt.step()
            train_loss += loss.item() * x.size(0)

        autoencoder.eval()
        for x, y in valid_loader:
            x = x.to(device)
            with torch.no_grad():
                z, x_hat = autoencoder(x)
                reconstruction_loss = ((x - x_hat)**2).sum()
                
                z_synth, x_hat_synth = autoencoder(x_hat)
                synthetic_loss = ((z_synth - z)**2).sum()
                
                loss = reconstruction_loss + 1 * synthetic_loss
                valid_loss += loss.item() * x.size(0)

        train_loss = train_loss / len(train_loader.dataset)
        valid_loss = valid_loss / len(valid_loader.dataset)

        losses['train'].append(train_loss)
        losses['validation'].append(valid_loss)

        # Save self.r values and x_hat at each epoch
        r_values.append(autoencoder.decoder.r.clone().detach().cpu().numpy())
        x_hat_values.append(x_hat.clone().detach().cpu().numpy())

        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, train_loss, valid_loss))

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                  valid_loss_min, valid_loss))
            valid_loss_min = valid_loss

    # Save losses to a CSV file
    loss_df = pd.DataFrame(losses)
    loss_df.to_csv("training_losses3.csv", index=False)

    # Convert the lists to numpy arrays
    r_values = np.array(r_values)
    x_hat_values = np.array(x_hat_values)

    return autoencoder, r_values, x_hat_values

# %%
latent_dims = 4
autoencoder = Autoencoder(latent_dims).to(device) # GPU
autoencoder, r_values, x_hat_values= train(autoencoder, train_loader,valid_loader,500)
# Out:
# Epoch: 0 	Training Loss: 3209.540373 	Validation Loss: 1439.842758
# Validation loss decreased (inf --> 1439.842758).  Saving model ...
# Epoch: 1 	Training Loss: 600.648279 	Validation Loss: 282.397620
# Validation loss decreased (1439.842758 --> 282.397620).  Saving model ...
# Epoch: 2 	Training Loss: 278.120475 	Validation Loss: 145.653612
# Validation loss decreased (282.397620 --> 145.653612).  Saving model ...
# Epoch: 3 	Training Loss: 182.643821 	Validation Loss: 118.404913
# Validation loss decreased (145.653612 --> 118.404913).  Saving model ...
# Epoch: 4 	Training Loss: 139.643491 	Validation Loss: 134.499000
# Epoch: 5 	Training Loss: 138.140317 	Validation Loss: 102.482797
# Validation loss decreased (118.404913 --> 102.482797).  Saving model ...
# Epoch: 6 	Training Loss: 125.898723 	Validation Loss: 82.299940
# Validation loss decreased (102.482797 --> 82.299940).  Saving model ...
# Epoch: 7 	Training Loss: 115.196885 	Validation Loss: 84.928604
# Epoch: 8 	Training Loss: 108.158911 	Validation Loss: 80.453077
# Validation loss decreased (82.299940 --> 80.453077).  Saving model ...
# Epoch: 9 	Training Loss: 122.231750 	Validation Loss: 110.558380
# Epoch: 10 	Training Loss: 95.579345 	Validation Loss: 85.035337
# Epoch: 11 	Training Loss: 82.009589 	Validation Loss: 71.739528
# Validation loss decreased (80.453077 --> 71.739528).  Saving model ...
# Epoch: 12 	Training Loss: 87.738023 	Validation Loss: 95.224818
# Epoch: 13 	Training Loss: 79.152356 	Validation Loss: 73.736591
# Epoch: 14 	Training Loss: 76.068250 	Validation Loss: 68.652209
# Validation loss decreased (71.739528 --> 68.652209).  Saving model ...
# Epoch: 15 	Training Loss: 68.501033 	Validation Loss: 43.426826
# Validation loss decreased (68.652209 --> 43.426826).  Saving model ...
# Epoch: 16 	Training Loss: 72.652020 	Validation Loss: 43.458277
# Epoch: 17 	Training Loss: 67.561170 	Validation Loss: 121.856125
# Epoch: 18 	Training Loss: 71.793080 	Validation Loss: 52.819529
# Epoch: 19 	Training Loss: 60.845053 	Validation Loss: 31.071082
# Validation loss decreased (43.426826 --> 31.071082).  Saving model ...
# Epoch: 20 	Training Loss: 60.550573 	Validation Loss: 132.576600
# Epoch: 21 	Training Loss: 68.203605 	Validation Loss: 48.774494
# Epoch: 22 	Training Loss: 61.074958 	Validation Loss: 41.460701
# Epoch: 23 	Training Loss: 61.776145 	Validation Loss: 62.362370
# Epoch: 24 	Training Loss: 59.837415 	Validation Loss: 46.061866
# Epoch: 25 	Training Loss: 56.051150 	Validation Loss: 57.817916
# Epoch: 26 	Training Loss: 72.562241 	Validation Loss: 63.725110
# Epoch: 27 	Training Loss: 54.967212 	Validation Loss: 39.430701
# Epoch: 28 	Training Loss: 58.149901 	Validation Loss: 39.575245
# Epoch: 29 	Training Loss: 53.991700 	Validation Loss: 36.958132
# Epoch: 30 	Training Loss: 59.001916 	Validation Loss: 93.058338
# Epoch: 31 	Training Loss: 57.616388 	Validation Loss: 28.421230
# Validation loss decreased (31.071082 --> 28.421230).  Saving model ...
# Epoch: 32 	Training Loss: 56.352748 	Validation Loss: 49.080575
# Epoch: 33 	Training Loss: 47.500161 	Validation Loss: 26.839738
# Validation loss decreased (28.421230 --> 26.839738).  Saving model ...
# Epoch: 34 	Training Loss: 48.651798 	Validation Loss: 30.385259
# Epoch: 35 	Training Loss: 52.578739 	Validation Loss: 70.195266
# Epoch: 36 	Training Loss: 54.005252 	Validation Loss: 32.372153
# Epoch: 37 	Training Loss: 60.137684 	Validation Loss: 85.579904
# Epoch: 38 	Training Loss: 57.912757 	Validation Loss: 45.256418
# Epoch: 39 	Training Loss: 56.268935 	Validation Loss: 36.591692
# Epoch: 40 	Training Loss: 50.898023 	Validation Loss: 37.049407
# Epoch: 41 	Training Loss: 55.757103 	Validation Loss: 35.004753
# Epoch: 42 	Training Loss: 54.313055 	Validation Loss: 35.143381
# Epoch: 43 	Training Loss: 51.030058 	Validation Loss: 29.431014
# Epoch: 44 	Training Loss: 52.385618 	Validation Loss: 35.148854
# Epoch: 45 	Training Loss: 55.084536 	Validation Loss: 32.262890
# Epoch: 46 	Training Loss: 46.439206 	Validation Loss: 64.421094
# Epoch: 47 	Training Loss: 48.160432 	Validation Loss: 46.546209
# Epoch: 48 	Training Loss: 56.519797 	Validation Loss: 45.852268
# Epoch: 49 	Training Loss: 50.760553 	Validation Loss: 46.103516
# Epoch: 50 	Training Loss: 62.051734 	Validation Loss: 44.868232
# Epoch: 51 	Training Loss: 49.352172 	Validation Loss: 41.354895
# Epoch: 52 	Training Loss: 49.774356 	Validation Loss: 29.392889
# Epoch: 53 	Training Loss: 46.889971 	Validation Loss: 54.720129
# Epoch: 54 	Training Loss: 54.424016 	Validation Loss: 56.805078
# Epoch: 55 	Training Loss: 57.588229 	Validation Loss: 63.487487
# Epoch: 56 	Training Loss: 44.547433 	Validation Loss: 34.595127
# Epoch: 57 	Training Loss: 51.974308 	Validation Loss: 55.393866
# Epoch: 58 	Training Loss: 47.779934 	Validation Loss: 24.938294
# Validation loss decreased (26.839738 --> 24.938294).  Saving model ...
# Epoch: 59 	Training Loss: 46.562404 	Validation Loss: 36.912822
# Epoch: 60 	Training Loss: 52.489224 	Validation Loss: 38.864020
# Epoch: 61 	Training Loss: 47.488317 	Validation Loss: 41.355820
# Epoch: 62 	Training Loss: 55.658682 	Validation Loss: 105.768280
# Epoch: 63 	Training Loss: 54.937044 	Validation Loss: 44.926722
# Epoch: 64 	Training Loss: 43.400105 	Validation Loss: 38.207246
# Epoch: 65 	Training Loss: 44.964409 	Validation Loss: 28.049440
# Epoch: 66 	Training Loss: 37.319496 	Validation Loss: 48.877105
# Epoch: 67 	Training Loss: 44.298182 	Validation Loss: 29.656248
# Epoch: 68 	Training Loss: 45.366686 	Validation Loss: 27.216993
# Epoch: 69 	Training Loss: 40.437782 	Validation Loss: 29.253835
# Epoch: 70 	Training Loss: 41.841474 	Validation Loss: 28.615320
# Epoch: 71 	Training Loss: 41.721194 	Validation Loss: 26.127762
# Epoch: 72 	Training Loss: 36.572808 	Validation Loss: 27.797222
# Epoch: 73 	Training Loss: 47.348582 	Validation Loss: 37.350245
# Epoch: 74 	Training Loss: 35.323241 	Validation Loss: 22.716247
# Validation loss decreased (24.938294 --> 22.716247).  Saving model ...
# Epoch: 75 	Training Loss: 34.065329 	Validation Loss: 19.028490
# Validation loss decreased (22.716247 --> 19.028490).  Saving model ...
# Epoch: 76 	Training Loss: 30.113014 	Validation Loss: 36.050412
# Epoch: 77 	Training Loss: 25.598763 	Validation Loss: 34.792333
# Epoch: 78 	Training Loss: 28.545600 	Validation Loss: 14.143664
# Validation loss decreased (19.028490 --> 14.143664).  Saving model ...
# Epoch: 79 	Training Loss: 27.831861 	Validation Loss: 12.939521
# Validation loss decreased (14.143664 --> 12.939521).  Saving model ...
# Epoch: 80 	Training Loss: 27.331561 	Validation Loss: 25.268057
# Epoch: 81 	Training Loss: 24.270229 	Validation Loss: 19.756245
# Epoch: 82 	Training Loss: 21.346509 	Validation Loss: 21.799788
# Epoch: 83 	Training Loss: 24.632331 	Validation Loss: 18.180727
# Epoch: 84 	Training Loss: 28.481912 	Validation Loss: 43.330188
# Epoch: 85 	Training Loss: 24.770795 	Validation Loss: 34.538008
# Epoch: 86 	Training Loss: 27.247624 	Validation Loss: 12.822670
# Validation loss decreased (12.939521 --> 12.822670).  Saving model ...
# Epoch: 87 	Training Loss: 22.719177 	Validation Loss: 43.586692
# Epoch: 88 	Training Loss: 26.729160 	Validation Loss: 17.864475
# Epoch: 89 	Training Loss: 23.408642 	Validation Loss: 46.473131
# Epoch: 90 	Training Loss: 33.610336 	Validation Loss: 20.775535
# Epoch: 91 	Training Loss: 28.089970 	Validation Loss: 19.134225
# Epoch: 92 	Training Loss: 30.013985 	Validation Loss: 11.293875
# Validation loss decreased (12.822670 --> 11.293875).  Saving model ...
# Epoch: 93 	Training Loss: 24.698134 	Validation Loss: 26.476386
# Epoch: 94 	Training Loss: 24.144447 	Validation Loss: 12.168865
# Epoch: 95 	Training Loss: 22.775254 	Validation Loss: 25.834604
# Epoch: 96 	Training Loss: 34.576062 	Validation Loss: 18.130423
# Epoch: 97 	Training Loss: 20.420092 	Validation Loss: 17.717379
# Epoch: 98 	Training Loss: 22.373806 	Validation Loss: 27.118391
# Epoch: 99 	Training Loss: 32.671159 	Validation Loss: 18.732544
# Epoch: 100 	Training Loss: 23.736730 	Validation Loss: 14.847907
# Epoch: 101 	Training Loss: 21.726114 	Validation Loss: 14.028789
# Epoch: 102 	Training Loss: 21.860129 	Validation Loss: 14.433082
# Epoch: 103 	Training Loss: 24.593563 	Validation Loss: 19.179375
# Epoch: 104 	Training Loss: 21.946548 	Validation Loss: 23.557437
# Epoch: 105 	Training Loss: 19.574477 	Validation Loss: 41.612800
# Epoch: 106 	Training Loss: 24.689588 	Validation Loss: 14.345826
# Epoch: 107 	Training Loss: 21.717635 	Validation Loss: 19.769907
# Epoch: 108 	Training Loss: 22.544525 	Validation Loss: 29.786765
# Epoch: 109 	Training Loss: 23.390699 	Validation Loss: 17.896909
# Epoch: 110 	Training Loss: 17.743355 	Validation Loss: 28.333580
# Epoch: 111 	Training Loss: 18.993746 	Validation Loss: 13.867928
# Epoch: 112 	Training Loss: 20.257064 	Validation Loss: 19.320805
# Epoch: 113 	Training Loss: 21.109829 	Validation Loss: 11.095045
# Validation loss decreased (11.293875 --> 11.095045).  Saving model ...
# Epoch: 114 	Training Loss: 16.538346 	Validation Loss: 12.067351
# Epoch: 115 	Training Loss: 15.485535 	Validation Loss: 10.510143
# Validation loss decreased (11.095045 --> 10.510143).  Saving model ...
# Epoch: 116 	Training Loss: 15.522368 	Validation Loss: 13.288045
# Epoch: 117 	Training Loss: 16.876958 	Validation Loss: 6.719779
# Validation loss decreased (10.510143 --> 6.719779).  Saving model ...
# Epoch: 118 	Training Loss: 19.343029 	Validation Loss: 9.358108
# Epoch: 119 	Training Loss: 17.484859 	Validation Loss: 51.174516
# Epoch: 120 	Training Loss: 19.947793 	Validation Loss: 9.102783
# Epoch: 121 	Training Loss: 15.007894 	Validation Loss: 7.401183
# Epoch: 122 	Training Loss: 19.522817 	Validation Loss: 9.260145
# Epoch: 123 	Training Loss: 14.119746 	Validation Loss: 6.211268
# Validation loss decreased (6.719779 --> 6.211268).  Saving model ...
# Epoch: 124 	Training Loss: 20.841446 	Validation Loss: 12.200608
# Epoch: 125 	Training Loss: 15.153500 	Validation Loss: 11.422550
# Epoch: 126 	Training Loss: 16.097177 	Validation Loss: 25.444844
# Epoch: 127 	Training Loss: 14.735955 	Validation Loss: 11.672183
# Epoch: 128 	Training Loss: 13.108011 	Validation Loss: 6.278342
# Epoch: 129 	Training Loss: 21.313340 	Validation Loss: 27.168854
# Epoch: 130 	Training Loss: 22.438823 	Validation Loss: 10.917083
# Epoch: 131 	Training Loss: 21.265574 	Validation Loss: 25.490298
# Epoch: 132 	Training Loss: 18.525549 	Validation Loss: 9.558722
# Epoch: 133 	Training Loss: 19.307670 	Validation Loss: 16.653046
# Epoch: 134 	Training Loss: 20.506956 	Validation Loss: 6.935497
# Epoch: 135 	Training Loss: 14.302415 	Validation Loss: 10.482255
# Epoch: 136 	Training Loss: 18.518943 	Validation Loss: 19.607846
# Epoch: 137 	Training Loss: 14.997759 	Validation Loss: 11.491892
# Epoch: 138 	Training Loss: 16.513353 	Validation Loss: 14.498840
# Epoch: 139 	Training Loss: 12.854583 	Validation Loss: 15.730793
# Epoch: 140 	Training Loss: 23.885939 	Validation Loss: 11.970968
# Epoch: 141 	Training Loss: 16.591781 	Validation Loss: 10.603972
# Epoch: 142 	Training Loss: 18.076663 	Validation Loss: 7.005867
# Epoch: 143 	Training Loss: 21.944705 	Validation Loss: 8.202225
# Epoch: 144 	Training Loss: 17.673946 	Validation Loss: 21.535573
# Epoch: 145 	Training Loss: 21.325746 	Validation Loss: 23.272870
# Epoch: 146 	Training Loss: 16.045478 	Validation Loss: 6.817231
# Epoch: 147 	Training Loss: 14.563644 	Validation Loss: 10.926766
# Epoch: 148 	Training Loss: 15.912158 	Validation Loss: 11.085937
# Epoch: 149 	Training Loss: 17.260123 	Validation Loss: 6.606647
# Epoch: 150 	Training Loss: 23.569410 	Validation Loss: 13.413465
# Epoch: 151 	Training Loss: 15.859694 	Validation Loss: 9.361583
# Epoch: 152 	Training Loss: 19.717640 	Validation Loss: 14.822874
# Epoch: 153 	Training Loss: 16.293623 	Validation Loss: 8.549081
# Epoch: 154 	Training Loss: 14.241358 	Validation Loss: 9.563684
# Epoch: 155 	Training Loss: 15.811115 	Validation Loss: 7.240203
# Epoch: 156 	Training Loss: 17.862054 	Validation Loss: 13.734687
# Epoch: 157 	Training Loss: 13.357134 	Validation Loss: 9.150496
# Epoch: 158 	Training Loss: 12.053464 	Validation Loss: 11.345781
# Epoch: 159 	Training Loss: 19.264899 	Validation Loss: 11.091375
# Epoch: 160 	Training Loss: 13.926893 	Validation Loss: 6.523679
# Epoch: 161 	Training Loss: 14.529884 	Validation Loss: 32.975984
# Epoch: 162 	Training Loss: 22.831038 	Validation Loss: 10.213981
# Epoch: 163 	Training Loss: 14.358886 	Validation Loss: 7.952709
# Epoch: 164 	Training Loss: 13.270449 	Validation Loss: 13.114530
# Epoch: 165 	Training Loss: 13.873096 	Validation Loss: 7.988259
# Epoch: 166 	Training Loss: 14.458351 	Validation Loss: 33.407973
# Epoch: 167 	Training Loss: 18.665539 	Validation Loss: 12.036441
# Epoch: 168 	Training Loss: 16.480285 	Validation Loss: 9.576434
# Epoch: 169 	Training Loss: 13.713606 	Validation Loss: 13.163843
# Epoch: 170 	Training Loss: 14.241786 	Validation Loss: 20.604158
# Epoch: 171 	Training Loss: 17.331037 	Validation Loss: 8.399319
# Epoch: 172 	Training Loss: 17.488789 	Validation Loss: 14.882458
# Epoch: 173 	Training Loss: 14.164773 	Validation Loss: 10.732494
# Epoch: 174 	Training Loss: 19.792636 	Validation Loss: 23.068550
# Epoch: 175 	Training Loss: 15.908649 	Validation Loss: 11.155029
# Epoch: 176 	Training Loss: 15.572219 	Validation Loss: 9.341947
# Epoch: 177 	Training Loss: 15.122693 	Validation Loss: 12.432359
# Epoch: 178 	Training Loss: 24.644651 	Validation Loss: 48.568996
# Epoch: 179 	Training Loss: 17.043581 	Validation Loss: 10.221666
# Epoch: 180 	Training Loss: 15.032755 	Validation Loss: 7.517355
# Epoch: 181 	Training Loss: 15.434212 	Validation Loss: 12.189837
# Epoch: 182 	Training Loss: 15.678030 	Validation Loss: 9.839247
# Epoch: 183 	Training Loss: 15.632833 	Validation Loss: 31.908513
# Epoch: 184 	Training Loss: 15.892303 	Validation Loss: 6.624195
# Epoch: 185 	Training Loss: 12.451280 	Validation Loss: 13.942867
# Epoch: 186 	Training Loss: 14.535364 	Validation Loss: 10.876343
# Epoch: 187 	Training Loss: 13.637197 	Validation Loss: 7.710096
# Epoch: 188 	Training Loss: 11.665407 	Validation Loss: 6.085771
# Validation loss decreased (6.211268 --> 6.085771).  Saving model ...
# Epoch: 189 	Training Loss: 13.260890 	Validation Loss: 12.059532
# Epoch: 190 	Training Loss: 14.680345 	Validation Loss: 8.826908
# Epoch: 191 	Training Loss: 10.975431 	Validation Loss: 39.906736
# Epoch: 192 	Training Loss: 15.535957 	Validation Loss: 11.521225
# Epoch: 193 	Training Loss: 17.443566 	Validation Loss: 5.360790
# Validation loss decreased (6.085771 --> 5.360790).  Saving model ...
# Epoch: 194 	Training Loss: 13.816661 	Validation Loss: 8.480813
# Epoch: 195 	Training Loss: 20.057818 	Validation Loss: 18.344811
# Epoch: 196 	Training Loss: 17.252378 	Validation Loss: 7.585169
# Epoch: 197 	Training Loss: 17.317597 	Validation Loss: 12.237390
# Epoch: 198 	Training Loss: 15.264154 	Validation Loss: 10.345167
# Epoch: 199 	Training Loss: 14.801432 	Validation Loss: 6.059267
# Epoch: 200 	Training Loss: 13.460134 	Validation Loss: 10.495023
# Epoch: 201 	Training Loss: 19.169295 	Validation Loss: 10.790035
# Epoch: 202 	Training Loss: 12.435420 	Validation Loss: 7.197288
# Epoch: 203 	Training Loss: 11.245056 	Validation Loss: 4.627728
# Validation loss decreased (5.360790 --> 4.627728).  Saving model ...
# Epoch: 204 	Training Loss: 13.200454 	Validation Loss: 9.268910
# Epoch: 205 	Training Loss: 12.679956 	Validation Loss: 8.027102
# Epoch: 206 	Training Loss: 10.952605 	Validation Loss: 6.065990
# Epoch: 207 	Training Loss: 17.078957 	Validation Loss: 15.602072
# Epoch: 208 	Training Loss: 17.198966 	Validation Loss: 20.553358
# Epoch: 209 	Training Loss: 14.811502 	Validation Loss: 10.185450
# Epoch: 210 	Training Loss: 12.674798 	Validation Loss: 10.045723
# Epoch: 211 	Training Loss: 13.916802 	Validation Loss: 7.009210
# Epoch: 212 	Training Loss: 17.127287 	Validation Loss: 15.622459
# Epoch: 213 	Training Loss: 16.356291 	Validation Loss: 11.187371
# Epoch: 214 	Training Loss: 16.213073 	Validation Loss: 25.954533
# Epoch: 215 	Training Loss: 18.244497 	Validation Loss: 9.551949
# Epoch: 216 	Training Loss: 15.759064 	Validation Loss: 13.687549
# Epoch: 217 	Training Loss: 19.869632 	Validation Loss: 18.055771
# Epoch: 218 	Training Loss: 18.195841 	Validation Loss: 7.860473
# Epoch: 219 	Training Loss: 16.610581 	Validation Loss: 11.858122
# Epoch: 220 	Training Loss: 12.850505 	Validation Loss: 7.228869
# Epoch: 221 	Training Loss: 13.986078 	Validation Loss: 8.657307
# Epoch: 222 	Training Loss: 16.021711 	Validation Loss: 14.289642
# Epoch: 223 	Training Loss: 10.879355 	Validation Loss: 17.757919
# Epoch: 224 	Training Loss: 11.524169 	Validation Loss: 6.607383
# Epoch: 225 	Training Loss: 12.215078 	Validation Loss: 11.778018
# Epoch: 226 	Training Loss: 18.361419 	Validation Loss: 9.871866
# Epoch: 227 	Training Loss: 13.953699 	Validation Loss: 20.853363
# Epoch: 228 	Training Loss: 16.925210 	Validation Loss: 25.653539
# Epoch: 229 	Training Loss: 12.768715 	Validation Loss: 26.328382
# Epoch: 230 	Training Loss: 15.622067 	Validation Loss: 25.343631
# Epoch: 231 	Training Loss: 16.237612 	Validation Loss: 6.682827
# Epoch: 232 	Training Loss: 11.391358 	Validation Loss: 6.903141
# Epoch: 233 	Training Loss: 13.452041 	Validation Loss: 5.573721
# Epoch: 234 	Training Loss: 14.685941 	Validation Loss: 10.476869
# Epoch: 235 	Training Loss: 15.961843 	Validation Loss: 8.502997
# Epoch: 236 	Training Loss: 16.306883 	Validation Loss: 6.545493
# Epoch: 237 	Training Loss: 13.598247 	Validation Loss: 16.786933
# Epoch: 238 	Training Loss: 15.331301 	Validation Loss: 14.532584
# Epoch: 239 	Training Loss: 13.325253 	Validation Loss: 7.995281
# Epoch: 240 	Training Loss: 12.044853 	Validation Loss: 9.406112
# Epoch: 241 	Training Loss: 11.735600 	Validation Loss: 8.689302
# Epoch: 242 	Training Loss: 12.319039 	Validation Loss: 17.585468
# Epoch: 243 	Training Loss: 13.602986 	Validation Loss: 26.210278
# Epoch: 244 	Training Loss: 11.698793 	Validation Loss: 17.030098
# Epoch: 245 	Training Loss: 19.984032 	Validation Loss: 9.347606
# Epoch: 246 	Training Loss: 13.373682 	Validation Loss: 14.624240
# Epoch: 247 	Training Loss: 13.183537 	Validation Loss: 8.738251
# Epoch: 248 	Training Loss: 10.981535 	Validation Loss: 4.495241
# Validation loss decreased (4.627728 --> 4.495241).  Saving model ...
# Epoch: 249 	Training Loss: 12.308333 	Validation Loss: 8.418877
# Epoch: 250 	Training Loss: 13.293022 	Validation Loss: 7.007578
# Epoch: 251 	Training Loss: 12.500024 	Validation Loss: 7.595355
# Epoch: 252 	Training Loss: 13.902029 	Validation Loss: 5.450668
# Epoch: 253 	Training Loss: 14.699721 	Validation Loss: 11.340711
# Epoch: 254 	Training Loss: 12.230314 	Validation Loss: 13.739746
# Epoch: 255 	Training Loss: 15.222363 	Validation Loss: 7.449033
# Epoch: 256 	Training Loss: 16.643102 	Validation Loss: 14.065406
# Epoch: 257 	Training Loss: 16.915449 	Validation Loss: 23.149823
# Epoch: 258 	Training Loss: 13.325642 	Validation Loss: 8.532893
# Epoch: 259 	Training Loss: 10.627972 	Validation Loss: 7.283374
# Epoch: 260 	Training Loss: 15.508919 	Validation Loss: 19.140594
# Epoch: 261 	Training Loss: 14.335098 	Validation Loss: 5.573976
# Epoch: 262 	Training Loss: 11.309768 	Validation Loss: 11.976802
# Epoch: 263 	Training Loss: 15.562295 	Validation Loss: 7.602230
# Epoch: 264 	Training Loss: 12.604983 	Validation Loss: 6.477859
# Epoch: 265 	Training Loss: 12.601138 	Validation Loss: 14.516434
# Epoch: 266 	Training Loss: 14.260822 	Validation Loss: 10.526910
# Epoch: 267 	Training Loss: 15.675398 	Validation Loss: 7.944493
# Epoch: 268 	Training Loss: 10.078659 	Validation Loss: 7.537777
# Epoch: 269 	Training Loss: 12.246306 	Validation Loss: 13.821701
# Epoch: 270 	Training Loss: 13.400156 	Validation Loss: 6.647875
# Epoch: 271 	Training Loss: 15.131693 	Validation Loss: 7.566621
# Epoch: 272 	Training Loss: 13.336663 	Validation Loss: 5.789558
# Epoch: 273 	Training Loss: 13.921289 	Validation Loss: 16.137315
# Epoch: 274 	Training Loss: 14.137691 	Validation Loss: 30.359700
# Epoch: 275 	Training Loss: 13.769345 	Validation Loss: 6.323644
# Epoch: 276 	Training Loss: 13.674677 	Validation Loss: 8.857730
# Epoch: 277 	Training Loss: 12.248972 	Validation Loss: 5.601328
# Epoch: 278 	Training Loss: 11.875525 	Validation Loss: 15.306101
# Epoch: 279 	Training Loss: 11.006088 	Validation Loss: 9.392914
# Epoch: 280 	Training Loss: 12.528680 	Validation Loss: 11.348228
# Epoch: 281 	Training Loss: 13.067379 	Validation Loss: 10.170828
# Epoch: 282 	Training Loss: 13.955484 	Validation Loss: 16.470657
# Epoch: 283 	Training Loss: 14.853731 	Validation Loss: 7.589707
# Epoch: 284 	Training Loss: 13.390990 	Validation Loss: 16.749736
# Epoch: 285 	Training Loss: 16.298580 	Validation Loss: 16.709979
# Epoch: 286 	Training Loss: 15.267793 	Validation Loss: 6.308502
# Epoch: 287 	Training Loss: 12.829339 	Validation Loss: 7.446082
# Epoch: 288 	Training Loss: 11.627479 	Validation Loss: 6.741167
# Epoch: 289 	Training Loss: 10.927203 	Validation Loss: 12.636825
# Epoch: 290 	Training Loss: 17.109478 	Validation Loss: 12.512211
# Epoch: 291 	Training Loss: 12.140120 	Validation Loss: 21.407158
# Epoch: 292 	Training Loss: 11.931277 	Validation Loss: 6.586333
# Epoch: 293 	Training Loss: 13.758467 	Validation Loss: 10.041657
# Epoch: 294 	Training Loss: 21.342865 	Validation Loss: 5.169618
# Epoch: 295 	Training Loss: 10.784253 	Validation Loss: 2.971633
# Validation loss decreased (4.495241 --> 2.971633).  Saving model ...
# Epoch: 296 	Training Loss: 14.556795 	Validation Loss: 16.945706
# Epoch: 297 	Training Loss: 17.477308 	Validation Loss: 13.555493
# Epoch: 298 	Training Loss: 12.038153 	Validation Loss: 7.545741
# Epoch: 299 	Training Loss: 10.433515 	Validation Loss: 6.809547
# Epoch: 300 	Training Loss: 11.111405 	Validation Loss: 28.405029
# Epoch: 301 	Training Loss: 16.499957 	Validation Loss: 8.221671
# Epoch: 302 	Training Loss: 13.048907 	Validation Loss: 4.969778
# Epoch: 303 	Training Loss: 11.778875 	Validation Loss: 17.779632
# Epoch: 304 	Training Loss: 16.823239 	Validation Loss: 7.715668
# Epoch: 305 	Training Loss: 10.914242 	Validation Loss: 3.721448
# Epoch: 306 	Training Loss: 12.845749 	Validation Loss: 9.532388
# Epoch: 307 	Training Loss: 9.727839 	Validation Loss: 5.418850
# Epoch: 308 	Training Loss: 13.255619 	Validation Loss: 6.033420
# Epoch: 309 	Training Loss: 11.352753 	Validation Loss: 8.862600
# Epoch: 310 	Training Loss: 11.467721 	Validation Loss: 5.667601
# Epoch: 311 	Training Loss: 11.763314 	Validation Loss: 13.539401
# Epoch: 312 	Training Loss: 11.748981 	Validation Loss: 6.238900
# Epoch: 313 	Training Loss: 14.266016 	Validation Loss: 7.095420
# Epoch: 314 	Training Loss: 13.465445 	Validation Loss: 17.459246
# Epoch: 315 	Training Loss: 13.560629 	Validation Loss: 19.404244
# Epoch: 316 	Training Loss: 17.737040 	Validation Loss: 26.896202
# Epoch: 317 	Training Loss: 17.855451 	Validation Loss: 7.694380
# Epoch: 318 	Training Loss: 10.002518 	Validation Loss: 7.580766
# Epoch: 319 	Training Loss: 10.372339 	Validation Loss: 8.312731
# Epoch: 320 	Training Loss: 9.679511 	Validation Loss: 11.395120
# Epoch: 321 	Training Loss: 10.525837 	Validation Loss: 6.815119
# Epoch: 322 	Training Loss: 12.725111 	Validation Loss: 4.971859
# Epoch: 323 	Training Loss: 13.609750 	Validation Loss: 9.017200
# Epoch: 324 	Training Loss: 11.378517 	Validation Loss: 31.408588
# Epoch: 325 	Training Loss: 14.047984 	Validation Loss: 15.125311
# Epoch: 326 	Training Loss: 14.335915 	Validation Loss: 5.969110
# Epoch: 327 	Training Loss: 13.010063 	Validation Loss: 7.606077
# Epoch: 328 	Training Loss: 10.645467 	Validation Loss: 5.649308
# Epoch: 329 	Training Loss: 10.619359 	Validation Loss: 17.253548
# Epoch: 330 	Training Loss: 13.018104 	Validation Loss: 17.508017
# Epoch: 331 	Training Loss: 15.908280 	Validation Loss: 5.736928
# Epoch: 332 	Training Loss: 12.881427 	Validation Loss: 5.880633
# Epoch: 333 	Training Loss: 11.308388 	Validation Loss: 22.947709
# Epoch: 334 	Training Loss: 12.395888 	Validation Loss: 11.110781
# Epoch: 335 	Training Loss: 14.848411 	Validation Loss: 5.485680
# Epoch: 336 	Training Loss: 10.588852 	Validation Loss: 5.393304
# Epoch: 337 	Training Loss: 10.687410 	Validation Loss: 8.593204
# Epoch: 338 	Training Loss: 11.238523 	Validation Loss: 13.725122
# Epoch: 339 	Training Loss: 13.500337 	Validation Loss: 5.509377
# Epoch: 340 	Training Loss: 12.615558 	Validation Loss: 9.589580
# Epoch: 341 	Training Loss: 12.510640 	Validation Loss: 9.120093
# Epoch: 342 	Training Loss: 10.586465 	Validation Loss: 8.402040
# Epoch: 343 	Training Loss: 12.915051 	Validation Loss: 5.430348
# Epoch: 344 	Training Loss: 11.514327 	Validation Loss: 7.180944
# Epoch: 345 	Training Loss: 11.206431 	Validation Loss: 14.417748
# Epoch: 346 	Training Loss: 12.413603 	Validation Loss: 6.254557
# Epoch: 347 	Training Loss: 10.121220 	Validation Loss: 6.843885
# Epoch: 348 	Training Loss: 11.975567 	Validation Loss: 13.227777
# Epoch: 349 	Training Loss: 13.211110 	Validation Loss: 6.833475
# Epoch: 350 	Training Loss: 13.623316 	Validation Loss: 25.519649
# Epoch: 351 	Training Loss: 10.904386 	Validation Loss: 4.305259
# Epoch: 352 	Training Loss: 19.525172 	Validation Loss: 13.342906
# Epoch: 353 	Training Loss: 12.846226 	Validation Loss: 8.987550
# Epoch: 354 	Training Loss: 14.283200 	Validation Loss: 5.971461
# Epoch: 355 	Training Loss: 12.730453 	Validation Loss: 11.045675
# Epoch: 356 	Training Loss: 13.235924 	Validation Loss: 13.918663
# Epoch: 357 	Training Loss: 17.667721 	Validation Loss: 13.051849
# Epoch: 358 	Training Loss: 12.208996 	Validation Loss: 9.416189
# Epoch: 359 	Training Loss: 9.749725 	Validation Loss: 4.789931
# Epoch: 360 	Training Loss: 11.058443 	Validation Loss: 5.226514
# Epoch: 361 	Training Loss: 11.552482 	Validation Loss: 5.626330
# Epoch: 362 	Training Loss: 10.657666 	Validation Loss: 6.299604
# Epoch: 363 	Training Loss: 10.628371 	Validation Loss: 4.767946
# Epoch: 364 	Training Loss: 9.510307 	Validation Loss: 9.284802
# Epoch: 365 	Training Loss: 11.686802 	Validation Loss: 6.079108
# Epoch: 366 	Training Loss: 10.588557 	Validation Loss: 5.722659
# Epoch: 367 	Training Loss: 10.535278 	Validation Loss: 4.571510
# Epoch: 368 	Training Loss: 11.693160 	Validation Loss: 8.728406
# Epoch: 369 	Training Loss: 10.332864 	Validation Loss: 6.850549
# Epoch: 370 	Training Loss: 9.243693 	Validation Loss: 15.073046
# Epoch: 371 	Training Loss: 12.864622 	Validation Loss: 6.686979
# Epoch: 372 	Training Loss: 10.251324 	Validation Loss: 7.474103
# Epoch: 373 	Training Loss: 11.802235 	Validation Loss: 7.655256
# Epoch: 374 	Training Loss: 9.886497 	Validation Loss: 4.794568
# Epoch: 375 	Training Loss: 7.966475 	Validation Loss: 4.794402
# Epoch: 376 	Training Loss: 9.034947 	Validation Loss: 6.150443
# Epoch: 377 	Training Loss: 10.512930 	Validation Loss: 5.090333
# Epoch: 378 	Training Loss: 11.096656 	Validation Loss: 9.400875
# Epoch: 379 	Training Loss: 14.601787 	Validation Loss: 8.254618
# Epoch: 380 	Training Loss: 10.618512 	Validation Loss: 15.054159
# Epoch: 381 	Training Loss: 9.850280 	Validation Loss: 6.266529
# Epoch: 382 	Training Loss: 12.545827 	Validation Loss: 5.751347
# Epoch: 383 	Training Loss: 11.710511 	Validation Loss: 8.915304
# Epoch: 384 	Training Loss: 10.289648 	Validation Loss: 9.458899
# Epoch: 385 	Training Loss: 10.706709 	Validation Loss: 4.059745
# Epoch: 386 	Training Loss: 9.908564 	Validation Loss: 4.952075
# Epoch: 387 	Training Loss: 9.969055 	Validation Loss: 8.716550
# Epoch: 388 	Training Loss: 10.104450 	Validation Loss: 5.077364
# Epoch: 389 	Training Loss: 11.603860 	Validation Loss: 10.713402
# Epoch: 390 	Training Loss: 12.966180 	Validation Loss: 5.691377
# Epoch: 391 	Training Loss: 9.051781 	Validation Loss: 6.801322
# Epoch: 392 	Training Loss: 10.485065 	Validation Loss: 6.141097
# Epoch: 393 	Training Loss: 11.252214 	Validation Loss: 10.012679
# Epoch: 394 	Training Loss: 10.940790 	Validation Loss: 9.862005
# Epoch: 395 	Training Loss: 12.567765 	Validation Loss: 14.500793
# Epoch: 396 	Training Loss: 12.820559 	Validation Loss: 5.180152
# Epoch: 397 	Training Loss: 10.806785 	Validation Loss: 8.426592
# Epoch: 398 	Training Loss: 12.564549 	Validation Loss: 9.115996
# Epoch: 399 	Training Loss: 13.115614 	Validation Loss: 4.388183
# Epoch: 400 	Training Loss: 15.131797 	Validation Loss: 28.155068
# Epoch: 401 	Training Loss: 16.350903 	Validation Loss: 7.568011
# Epoch: 402 	Training Loss: 10.022896 	Validation Loss: 6.224393
# Epoch: 403 	Training Loss: 10.008502 	Validation Loss: 3.602621
# Epoch: 404 	Training Loss: 10.364383 	Validation Loss: 3.706442
# Epoch: 405 	Training Loss: 10.051792 	Validation Loss: 7.736380
# Epoch: 406 	Training Loss: 10.401468 	Validation Loss: 11.124930
# Epoch: 407 	Training Loss: 9.412664 	Validation Loss: 8.891506
# Epoch: 408 	Training Loss: 10.848131 	Validation Loss: 6.521346
# Epoch: 409 	Training Loss: 9.364413 	Validation Loss: 3.934384
# Epoch: 410 	Training Loss: 9.762498 	Validation Loss: 7.016724
# Epoch: 411 	Training Loss: 12.923313 	Validation Loss: 5.229905
# Epoch: 412 	Training Loss: 11.331062 	Validation Loss: 7.841936
# Epoch: 413 	Training Loss: 10.467689 	Validation Loss: 11.481439
# Epoch: 414 	Training Loss: 12.079606 	Validation Loss: 9.999974
# Epoch: 415 	Training Loss: 12.599304 	Validation Loss: 6.466516
# Epoch: 416 	Training Loss: 12.982040 	Validation Loss: 11.417652
# Epoch: 417 	Training Loss: 10.877607 	Validation Loss: 4.720307
# Epoch: 418 	Training Loss: 10.631684 	Validation Loss: 7.510005
# Epoch: 419 	Training Loss: 10.496185 	Validation Loss: 5.976919
# Epoch: 420 	Training Loss: 10.873424 	Validation Loss: 4.111795
# Epoch: 421 	Training Loss: 9.807793 	Validation Loss: 3.711114
# Epoch: 422 	Training Loss: 10.329260 	Validation Loss: 4.083695
# Epoch: 423 	Training Loss: 11.776714 	Validation Loss: 12.716958
# Epoch: 424 	Training Loss: 12.331000 	Validation Loss: 6.494318
# Epoch: 425 	Training Loss: 9.292504 	Validation Loss: 6.559437
# Epoch: 426 	Training Loss: 10.124020 	Validation Loss: 11.700720
# Epoch: 427 	Training Loss: 10.962090 	Validation Loss: 7.745424
# Epoch: 428 	Training Loss: 9.934250 	Validation Loss: 16.541238
# Epoch: 429 	Training Loss: 11.204816 	Validation Loss: 4.614724
# Epoch: 430 	Training Loss: 9.587413 	Validation Loss: 11.466566
# Epoch: 431 	Training Loss: 9.007026 	Validation Loss: 7.034547
# Epoch: 432 	Training Loss: 12.263593 	Validation Loss: 10.090031
# Epoch: 433 	Training Loss: 10.283127 	Validation Loss: 44.547787
# Epoch: 434 	Training Loss: 15.200430 	Validation Loss: 11.964509
# Epoch: 435 	Training Loss: 10.782686 	Validation Loss: 7.251872
# Epoch: 436 	Training Loss: 10.836104 	Validation Loss: 5.348663
# Epoch: 437 	Training Loss: 9.646349 	Validation Loss: 5.121960
# Epoch: 438 	Training Loss: 11.737011 	Validation Loss: 10.179208
# Epoch: 439 	Training Loss: 10.914776 	Validation Loss: 6.817901
# Epoch: 440 	Training Loss: 11.932741 	Validation Loss: 6.481842
# Epoch: 441 	Training Loss: 10.895928 	Validation Loss: 31.008303
# Epoch: 442 	Training Loss: 15.488668 	Validation Loss: 4.445283
# Epoch: 443 	Training Loss: 9.811557 	Validation Loss: 9.658977
# Epoch: 444 	Training Loss: 11.687087 	Validation Loss: 9.282767
# Epoch: 445 	Training Loss: 11.266437 	Validation Loss: 7.074243
# Epoch: 446 	Training Loss: 10.747233 	Validation Loss: 6.339337
# Epoch: 447 	Training Loss: 9.970473 	Validation Loss: 7.900024
# Epoch: 448 	Training Loss: 10.397802 	Validation Loss: 3.530587
# Epoch: 449 	Training Loss: 8.877057 	Validation Loss: 3.847790
# Epoch: 450 	Training Loss: 9.323242 	Validation Loss: 5.910072
# Epoch: 451 	Training Loss: 9.808073 	Validation Loss: 7.168175
# Epoch: 452 	Training Loss: 9.839630 	Validation Loss: 3.616514
# Epoch: 453 	Training Loss: 8.815465 	Validation Loss: 7.928686
# Epoch: 454 	Training Loss: 9.836929 	Validation Loss: 4.772534
# Epoch: 455 	Training Loss: 8.714844 	Validation Loss: 18.792498
# Epoch: 456 	Training Loss: 11.017880 	Validation Loss: 9.645891
# Epoch: 457 	Training Loss: 11.473682 	Validation Loss: 5.124221
# Epoch: 458 	Training Loss: 11.390867 	Validation Loss: 5.993628
# Epoch: 459 	Training Loss: 11.555318 	Validation Loss: 7.395955
# Epoch: 460 	Training Loss: 9.428113 	Validation Loss: 5.487888
# Epoch: 461 	Training Loss: 12.561819 	Validation Loss: 10.521000
# Epoch: 462 	Training Loss: 11.616975 	Validation Loss: 5.861971
# Epoch: 463 	Training Loss: 9.405105 	Validation Loss: 8.810896
# Epoch: 464 	Training Loss: 10.868062 	Validation Loss: 6.116901
# Epoch: 465 	Training Loss: 9.856909 	Validation Loss: 7.314366
# Epoch: 466 	Training Loss: 10.661505 	Validation Loss: 9.454086
# Epoch: 467 	Training Loss: 12.239890 	Validation Loss: 14.963763
# Epoch: 468 	Training Loss: 15.504725 	Validation Loss: 11.825889
# Epoch: 469 	Training Loss: 11.610890 	Validation Loss: 4.390755
# Epoch: 470 	Training Loss: 11.497102 	Validation Loss: 10.096530
# Epoch: 471 	Training Loss: 10.708256 	Validation Loss: 4.738899
# Epoch: 472 	Training Loss: 11.478554 	Validation Loss: 8.577817
# Epoch: 473 	Training Loss: 8.994577 	Validation Loss: 5.365113
# Epoch: 474 	Training Loss: 10.009498 	Validation Loss: 5.624851
# Epoch: 475 	Training Loss: 9.632165 	Validation Loss: 7.992377
# Epoch: 476 	Training Loss: 10.433449 	Validation Loss: 14.647336
# Epoch: 477 	Training Loss: 9.575286 	Validation Loss: 6.167105
# Epoch: 478 	Training Loss: 10.056778 	Validation Loss: 9.761583
# Epoch: 479 	Training Loss: 9.893614 	Validation Loss: 4.458741
# Epoch: 480 	Training Loss: 8.579823 	Validation Loss: 7.732419
# Epoch: 481 	Training Loss: 8.492328 	Validation Loss: 4.488253
# Epoch: 482 	Training Loss: 9.056741 	Validation Loss: 5.632766
# Epoch: 483 	Training Loss: 10.026871 	Validation Loss: 7.760657
# Epoch: 484 	Training Loss: 12.416092 	Validation Loss: 13.793963
# Epoch: 485 	Training Loss: 13.524678 	Validation Loss: 4.965583
# Epoch: 486 	Training Loss: 9.326555 	Validation Loss: 5.924117
# Epoch: 487 	Training Loss: 9.323295 	Validation Loss: 7.000990
# Epoch: 488 	Training Loss: 10.866574 	Validation Loss: 4.469551
# Epoch: 489 	Training Loss: 9.416730 	Validation Loss: 4.277887
# Epoch: 490 	Training Loss: 9.745272 	Validation Loss: 8.923473
# Epoch: 491 	Training Loss: 11.152603 	Validation Loss: 10.762836
# Epoch: 492 	Training Loss: 10.601803 	Validation Loss: 5.256945
# Epoch: 493 	Training Loss: 9.654550 	Validation Loss: 13.726777
# Epoch: 494 	Training Loss: 12.174249 	Validation Loss: 4.658673
# Epoch: 495 	Training Loss: 8.936437 	Validation Loss: 9.397801
# Epoch: 496 	Training Loss: 10.007668 	Validation Loss: 8.726933
# Epoch: 497 	Training Loss: 10.513574 	Validation Loss: 4.044373
# Epoch: 498 	Training Loss: 9.559068 	Validation Loss: 3.828173
# Epoch: 499 	Training Loss: 8.595909 	Validation Loss: 9.482648

# %%
spectras=autoencoder.decoder.r.clone().detach().cpu().numpy()
spectras[spectras<0]=0
filtered_2 =[spectras[0],spectras[1]]
filtered_2= pd.DataFrame(filtered_2)
# filtered_2.to_csv('filtered_new_2.csv',index=False)

# %%
v = np.linspace(2900, 3100, 600)  # Example x-values
# df2=[df1[2] , df1[1]]
plt.plot(v,-spectras[3])
# plt.plot(v,spectras[3]/2.2)
# spectras[3]=spectras
plt.plot(v,prop_abs[:,4])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter


Exper = [-met_abs[:,4], -eth_abs[:,4], -ethy_abs[:,4]/2,-prop_abs[:,4]]

species = ['$CH_4$', '$C_2H_6$', '$C_2H_4$', '$C_3H_4$']

v = np.linspace(2989.5, 2984.5, 600)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Define colors for each species

fig, axes = plt.subplots(2, 1, figsize=(16, 14), sharex=True, gridspec_kw={'height_ratios': [4, 1]})

# Plotting spectras_updated and Exper with filled areas
for i in range(4):
    axes[0].plot(v, spectras[i], label=f'{species[i]}', color=colors[i], linewidth=3)
    axes[0].fill_between(v, 0, spectras[i], color=colors[i], alpha=0.3)
    axes[0].plot(v, Exper[i], color=colors[i], linestyle='--', linewidth=3)
    axes[0].fill_between(v, 0, Exper[i], facecolor='none', edgecolor=colors[i], hatch='//', linewidth=0.0)

# Adding the text inside the first subplot at the top
axes[0].text(0.66, 0.95, 'Solid fill: Reconstructed by UnblindMix', 
             verticalalignment='top', horizontalalignment='right', 
             transform=axes[0].transAxes, fontsize=30)

axes[0].tick_params(axis='both', which='major', labelsize=25)
axes[0].legend(fontsize=25, loc='lower right', ncol=1, bbox_to_anchor=(1, 0))

# Plotting residuals with hashed pattern
for i in range(4):
    residuals = spectras[i] + Exper[i]
    weighted_error = np.sum((residuals)) / np.sum(np.abs(Exper[i])) * 100
    axes[1].plot(v, residuals, linestyle='--', linewidth=3, label=f'Residuals - {species[i]} (Weighted Error: {weighted_error:.2f}%)', color=colors[i])

axes[1].axhline(y=0, color='black', linestyle=':', linewidth=3)  # Add horizontal line at y=0 for reference
axes[1].tick_params(axis='both', which='major', labelsize=25)

axes[1].text(0.72, 1.65, 'Hashed: Measured spectra at 673 K ', 
             verticalalignment='bottom', horizontalalignment='right', 
             transform=axes[1].transAxes, fontsize=30)

for ax in axes:
    ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.1f}'.format(abs(x))))

# Set common x and y labels for the entire figure
fig.text(0.5, 0.01, 'Wavenumber (cm$^{-1}$)', ha='center', fontsize=36)
fig.text(0.05, 0.59, 'Absorbance', va='center', rotation='vertical', fontsize=36)
fig.text(0.05, 0.17, 'Residuals (%)', va='center', rotation='vertical', fontsize=36)
plt.style.use('dark_background')

# Save the figure if needed
# plt.savefig('/home/sym/ASPACC BSS/plots/results_673_dark.pdf', transparent=True, dpi=300)
# plt.savefig('/home/sym/ASPACC BSS/plots/results_673_dark.png', transparent=True, dpi=150)
# # plt.savefig('/home/sym/BSS/paper_figures/experiments/exp_recons_filled_dark.pdf', transparent=True, dpi=600)
plt.show()

# %%
import numpy as np
from sklearn.decomposition import NMF

# 1) Your non-negative data matrix (Nobs × n_features)
X = paired_signals_2[:1000, :600]         # e.g. first 602 cols
X_nonneg = X - X.min()           # shift into >=0

# 2) Your H_init from the spectra (n_components × n_features)
H_init = stacked_tensors.cpu().numpy().astype(np.float64)  # shape (4, 602)
H_init = np.clip(H_init, 0, None)                          # ensure non-neg

n_samples, n_features = X_nonneg.shape
n_components = H_init.shape[0]

# 3) Make a random non-negative W_init
rng = np.random.default_rng(seed=0)
W_init = rng.random((n_samples, n_components), dtype=np.float64)

# 4) Build the NMF model with custom init
model = NMF(
    n_components=n_components,
    init='custom',
    tol=1e-5,
    max_iter=1000,
    random_state=0
)

# 5) Pass both W_init and H_init to fit_transform
W = model.fit_transform(X_nonneg, W=W_init, H=H_init)
H = model.components_

print("W shape:", W.shape)  # (Nobs, 4)
print("H shape:", H.shape)  # (4, 602)
# Out:
# W shape: (1000, 4)
# H shape: (4, 600)
# /sw/rl9g/machine_learning/2024.01/rl9_cudnn8_cuda11.8_py3.9_env/machine_learning-module/env/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1665: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

# Assuming 'spectras_updated', '-CH4', '-C2H6', '-C2H4', '-C3H4' are defined elsewhere in your code

# spectras_updated = [spectras[0], spectras[2], spectras[3], spectras[1]]
Exper = [-met_abs[:,4], -eth_abs[:,4], -ethy_abs[:,4]/2,-prop_abs[:,4]]

species = ['$CH_4$', '$C_2H_6$', '$C_2H_4$', '$C_3H_4$']

v = np.linspace(2989.5, 2984.5, 600)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Define colors for each species

fig, axes = plt.subplots(2, 1, figsize=(16, 14), sharex=True, gridspec_kw={'height_ratios': [4, 1]})

# Plotting spectras_updated and Exper with filled areas
for i in range(4):
    axes[0].plot(v, H[i], label=f'{species[i]}', color=colors[i], linewidth=3)
    axes[0].fill_between(v, 0, H[i], color=colors[i], alpha=0.3)
    axes[0].plot(v, Exper[i], color=colors[i], linestyle='--', linewidth=3)
    axes[0].fill_between(v, 0, Exper[i], facecolor='none', edgecolor=colors[i], hatch='//', linewidth=0.0)

# Adding the text inside the first subplot at the top
axes[0].text(0.66, 0.95, 'Solid fill: Reconstructed by UnblindMix', 
             verticalalignment='top', horizontalalignment='right', 
             transform=axes[0].transAxes, fontsize=30)

axes[0].tick_params(axis='both', which='major', labelsize=25)
axes[0].legend(fontsize=25, loc='lower right', ncol=1, bbox_to_anchor=(1, 0))

# Plotting residuals with hashed pattern
for i in range(4):
    residuals = H[i] + Exper[i]
    weighted_error = np.sum((residuals)) / np.sum(np.abs(Exper[i])) * 100
    axes[1].plot(v, residuals, linestyle='--', linewidth=3, label=f'Residuals - {species[i]} (Weighted Error: {weighted_error:.2f}%)', color=colors[i])

axes[1].axhline(y=0, color='black', linestyle=':', linewidth=3)  # Add horizontal line at y=0 for reference
axes[1].tick_params(axis='both', which='major', labelsize=25)

axes[1].text(0.72, 1.65, 'Hashed: Measured spectra at 673 K ', 
             verticalalignment='bottom', horizontalalignment='right', 
             transform=axes[1].transAxes, fontsize=30)

for ax in axes:
    ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: '{:.1f}'.format(abs(x))))

# Set common x and y labels for the entire figure
fig.text(0.5, 0.01, 'Wavenumber (cm$^{-1}$)', ha='center', fontsize=36)
fig.text(0.05, 0.59, 'Absorbance', va='center', rotation='vertical', fontsize=36)
fig.text(0.05, 0.17, 'Residuals', va='center', rotation='vertical', fontsize=36)

# Adjust layout to ensure there is no overlap
# # plt.tight_layout(rect=[0.04, 0.04, 1, 1])
# plt.style.use('default')
# plt.style.use('default')
plt.style.use('dark_background')

plt.show()
